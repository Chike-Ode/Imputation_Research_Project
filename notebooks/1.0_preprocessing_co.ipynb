# %% [markdown]
# # Imputation Research Project - Notebook 1 (Preprocessing)

# %% [markdown]
# ## Step 1

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from src.preprocessing.preprocessing import NumericalVariableCleaner, NumericalMasker 
import os
from pathlib import Path
from notebook_config import ROOT_DIR
ROOT_DIR = ROOT_DIR.as_posix() 
import json

# %%
print(ROOT_DIR)
# Out:
# C:/Users/Chike/Desktop/HEC/Fall_2022/Machine_Learning_1/Assignments/imputation_research

# %%
nutrition_df = pd.read_csv(f'{ROOT_DIR}/data/raw/nutrition.csv',index_col = 0)
nutrition_df
# Out:
#                                                    name serving_size  \
# 0                                            Cornstarch        100 g
# 1                                          Nuts, pecans        100 g
# 2                                         Eggplant, raw        100 g
# 3                                        Teff, uncooked        100 g
# 4                                       Sherbet, orange        100 g
# ...                                                 ...          ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8785  Lamb, cooked, separable lean only, composite o...        100 g
# 8786  Lamb, raw, separable lean and fat, composite o...        100 g
# 8787  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8788  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
#
#       calories total_fat saturated_fat cholesterol    sodium  choline  \
# ...

# %%
cleaner = NumericalVariableCleaner()
nutrition_clean_df = cleaner.clean(nutrition_df,col_ignore = ['name'])
# Out:
# INFO:root:Cleaning numerical fields.
# INFO:root:Stored data frame inside object.
# INFO:root:Selecting columns to clean.
# INFO:root:Columns to clean is not specified.
# INFO:root:Dropping the following specified columns: ['name']
# INFO:root:Cleaning the following fields: ['serving_size' 'calories' 'total_fat' 'saturated_fat' 'cholesterol'
#  'sodium' 'choline' 'folate' 'folic_acid' 'niacin' 'pantothenic_acid'
#  'riboflavin' 'thiamin' 'vitamin_a' 'vitamin_a_rae' 'carotene_alpha'
#  'carotene_beta' 'cryptoxanthin_beta' 'lutein_zeaxanthin' 'lucopene'
#  'vitamin_b12' 'vitamin_b6' 'vitamin_c' 'vitamin_d' 'vitamin_e'
#  'tocopherol_alpha' 'vitamin_k' 'calcium' 'copper' 'irom' 'magnesium'
#  'manganese' 'phosphorous' 'potassium' 'selenium' 'zink' 'protein'
#  'alanine' 'arginine' 'aspartic_acid' 'cystine' 'glutamic_acid' 'glycine'
#  'histidine' 'hydroxyproline' 'isoleucine' 'leucine' 'lysine' 'methionine'
#  'phenylalanine' 'proline' 'serine' 'threonine' 'tryptophan' 'tyrosine'
# ...

# %%
cleaner._measure_units
# Out:
# {'serving_size': ['g'],
#  'total_fat': ['g'],
#  'saturated_fat': ['g'],
#  'cholesterol': ['mg'],
#  'sodium': ['mg'],
#  'choline': ['mg'],
#  'folate': ['mcg'],
#  'folic_acid': ['mcg'],
#  'niacin': ['mg'],
#  'pantothenic_acid': ['mg'],
#  'riboflavin': ['mg'],
#  'thiamin': ['mg'],
#  'vitamin_a': ['mcg'],
#  'vitamin_a_rae': ['mcg'],
#  'carotene_alpha': ['mcg'],
#  'carotene_beta': ['mcg'],
#  'cryptoxanthin_beta': ['mcg'],
#  'lutein_zeaxanthin': ['mcg'],
#  'vitamin_b12': ['mcg'],
#  'vitamin_b6': ['mg'],
#  'vitamin_c': ['mg'],
#  'vitamin_d': [],
#  'vitamin_e': ['mg'],
#  'tocopherol_alpha': ['mg'],
#  'vitamin_k': ['mcg'],
#  'calcium': ['mg'],
#  'copper': ['mg'],
#  'irom': ['mg'],
#  'magnesium': ['mg'],
#  'manganese': ['mg'],
#  'phosphorous': ['mg'],
#  'potassium': ['mg'],
#  'selenium': ['mcg'],
#  'zink': ['mg'],
#  'protein': ['g'],
#  'alanine': ['g'],
#  'arginine': ['g'],
#  'aspartic_acid': ['g'],
#  'cystine': ['g'],
#  'glutamic_acid': ['g'],
# ...

# %%
nutrition_clean_df
# Out:
#                                                    name  serving_size  \
# 0                                            Cornstarch           100
# 1                                          Nuts, pecans           100
# 2                                         Eggplant, raw           100
# 3                                        Teff, uncooked           100
# 4                                       Sherbet, orange           100
# ...                                                 ...           ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...           100
# 8785  Lamb, cooked, separable lean only, composite o...           100
# 8786  Lamb, raw, separable lean and fat, composite o...           100
# 8787  Beef, raw, all grades, trimmed to 0" fat, sepa...           100
# 8788  Beef, raw, all grades, trimmed to 0" fat, sepa...           100
#
#       total_fat  saturated_fat  cholesterol  sodium  choline  folate  \
# ...

# %%
nutrition_clean_df.to_csv(f'{ROOT_DIR}/data/interim/nutrition_numerical.csv', index=False)

# %%
with open(f'{ROOT_DIR}/data/interim/nutrient_measure_units.json', 'w') as fp:
    json.dump(cleaner._measure_units, fp)
